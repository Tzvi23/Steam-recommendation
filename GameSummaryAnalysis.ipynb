# %%
import pandas as pd
import sklearn as sk
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import math

# %%
data = pd.read_csv('summaryAnalyze/game_summary.csv')
data.head()
# Out:
#                     game_name  \
# 0  The Elder Scrolls V Skyrim
# 1                   Fallout 4
# 2                       Spore
# 3           Fallout New Vegas
# 4               Left 4 Dead 2
#
#                                              summary
# 0  The next chapter in the highly anticipated Eld...
# 1  Bethesda Game Studios, the award-winning creat...
# 2                                                 -1
# 3  In this first-person Western RPG, the player t...
# 4  Left 4 Dead 2 is a cooperative first-person sh...

# %%
data_processed = data[data.summary != '-1']['summary']
all_data_processed = data[data.summary != '-1']
data_updated = data_processed.tolist()

# %%
all_data_processed = all_data_processed['game_name'].tolist()
all_data_processed
# Out:
# ['The Elder Scrolls V Skyrim',
#  'Fallout 4',
#  'Fallout New Vegas',
#  'Left 4 Dead 2',
#  'HuniePop',
#  'Path of Exile',
#  'Poly Bridge',
#  'Left 4 Dead',
#  'Team Fortress 2',
#  'Tomb Raider',
#  'The Banner Saga',
#  'Dead Island Epidemic',
#  'BioShock Infinite',
#  'Dragon Age Origins - Ultimate Edition',
#  'SEGA Genesis & Mega Drive Classics',
#  'Grand Theft Auto IV',
#  'Realm of the Mad God',
#  'Marvel Heroes 2015',
#  'Eldevin',
#  'Dota 2',
#  'BioShock',
#  'Robocraft',
#  "Garry's Mod",
#  'Jazzpunk',
#  'Alan Wake',
#  'BioShock 2',
#  'Fallen Earth',
#  "Fallout New Vegas Courier's Stash",
#  'Fallout New Vegas Dead Money',
#  'Fallout New Vegas Honest Hearts',
#  'Grand Theft Auto Episodes from Liberty City',
#  'Hitman Absolution',
#  'The Elder Scrolls V Skyrim - Dawnguard',
#  'The Elder Scrolls V Skyrim - Dragonborn',
#  'The Elder Scrolls V Skyrim - Hearthfire',
#  'Ultra Street Fighter IV',
#  'FINAL FANTASY XIII',
#  "Sid Meier's Civilization V",
#  'L.A. Noire',
#  'Company of Heroes Tales of Valor',
#  '7 Days to Die',
#  'Divekick',
#  'FINAL FANTASY VII',
#  'Orcs Must Die! 2',
#  'Killing Floor',
#  'Company of Heroes',
#  'Bastion',
#  'Undertale',
#  'Counter-Strike Global Offensive',
#  'Orcs Must Die!',
#  'THE KING OF FIGHTERS XIII STEAM EDITION',
#  'GUILTY GEAR XX ACCENT CORE PLUS R',
#  'Skullgirls',
#  "Assassin's Creed II",
#  'Company of Heroes Opposing Fronts',
#  'Guilty Gear X2 #Reload',
#  'Psychonauts',
#  'Company of Heroes 2',
#  'Magicka',
#  'Magicka Vietnam',
#  'Natural Selection 2',
#  'Sanctum',
#  'Sanctum 2',
#  'Serious Sam 3 BFE',
#  'Grand Theft Auto V',
#  'Insurgency',
#  'METAL GEAR SOLID V THE PHANTOM PAIN',
#  'S.T.A.L.K.E.R. Shadow of Chernobyl',
#  'S.T.A.L.K.E.R. Call of Pripyat',
#  'Saints Row The Third',
#  'Far Cry 3',
#  'S.T.A.L.K.E.R. Clear Sky',
#  'Rocket League',
#  'Far Cry 4',
#  'Prototype',
#  'Space Pirates and Zombies',
#  'Dying Light',
#  'Just Cause 2',
#  "Mirror's Edge",
#  'Mad Max',
#  'Portal 2',
#  'Deus Ex Human Revolution',
#  'Middle-earth Shadow of Mordor',
#  'RUNNING WITH RIFLES',
#  'Tropico 4',
#  'Cave Story+',
#  'Dust An Elysian Tail',
#  'F.E.A.R.',
#  'South Park The Stick of Truth',
#  'Sleeping Dogs',
#  'Watch_Dogs',
#  'Saints Row IV',
#  'DayZ',
#  'Half-Life 2',
#  'Reassembly',
#  "Sid Meier's Civilization III Complete",
#  'The Talos Principle',
#  'DiRT 3',
#  'FTL Faster Than Light',
#  'Age of Empires II HD Edition',
#  'Batman Arkham Asylum GOTY Edition',
#  'Gunpoint',
#  'Rebuild 3 Gangs of Deadsville',
#  "Recettear An Item Shop's Tale",
#  'Metro 2033',
#  'Monaco',
#  'Overgrowth',
#  "Assassin's Creed III",
#  'Ori and the Blind Forest',
#  'Far Cry 3 Blood Dragon',
#  'Burnout Paradise The Ultimate Box',
#  'PROTOTYPE 2',
#  'Game Dev Tycoon',
#  'Sniper Elite 3',
#  'Gratuitous Space Battles',
#  'Rogue Legacy',
#  'Plague Inc Evolved',
#  'From Dust',
#  'Next Car Game Wreckfest',
#  'Rivals of Aether',
#  'Half-Life 2 Episode Two',
#  'Rise of Nations Extended Edition',
#  'Nidhogg',
#  'Spec Ops The Line',
#  'Dishonored',
#  'Half-Life 2 Episode One',
#  'Wolfenstein The New Order',
#  'Distance',
#  'Epic Battle Fantasy 4',
#  'Metro Last Light',
#  'Miasmata',
#  'Dead Space',
#  'Hotline Miami',
#  'NOT A HERO',
#  'Receiver',
#  'Crypt of the NecroDancer',
#  'Portal',
#  'F.E.A.R. 2 Project Origin',
#  'NaissanceE',
#  'SteamWorld Dig',
#  'Kairo',
#  'The Binding of Isaac',
#  'LEGO The Lord of the Rings',
#  'METAL GEAR RISING REVENGEANCE',
#  'Starpoint Gemini 2',
#  'The Vanishing of Ethan Carter',
#  'Goat Simulator',
#  'Mass Effect',
#  'Arma 2 Operation Arrowhead',
#  'METAL GEAR SOLID V GROUND ZEROES',
#  'Banished',
#  'DiRT Showdown',
#  'Sonic Adventure 2 ',
#  'Battlestations Midway',
#  'HOARD',
#  'Sunless Sea',
#  'Mark of the Ninja',
#  'Creeper World 3 Arc Eternal',
#  'Turbo Dismount',
#  'Floating Point',
#  'Grow Home',
#  'LUFTRAUSERS',
#  'Arma 2',
#  'No Time To Explain Remastered',
#  'FEZ',
#  'Delver',
#  'The Legend of Heroes Trails in the Sky',
#  'Evoland',
#  'Bleed',
#  'Borderlands 2',
#  'Race The Sun',
#  'Shadowgrounds',
#  'They Bleed Pixels',
#  'Trine',
#  'Sir, You Are Being Hunted',
#  'Symphony',
#  'DLC Quest',
#  'Far Cry 2',
#  'The Stanley Parable',
#  'Freedom Planet',
#  'KHOLAT',
#  'Osmos',
#  'Oil Rush',
#  'Unepic',
#  'The Legend of Korra',
#  '404Sight',
#  'Dark Souls Prepare to Die Edition',
#  'Gravity Ghost',
#  'Rock of Ages',
#  'Half-Life 2 Lost Coast',
#  'Galcon Legends',
#  'Air Brawl',
#  'Cat Goes Fishing',
#  'One Finger Death Punch',
#  'Mind Path to Thalamus Enhanced Edition',
#  'Intrusion 2',
#  'Amnesia The Dark Descent',
#  'Fieldrunners',
#  'Out There Somewhere',
#  'KAMI',
#  "Lone Survivor The Director's Cut",
#  'NightSky',
#  'Frozen Synapse',
#  'Hammerfight',
#  'Spintires',
#  'Ziggurat',
#  'AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome',
#  'Dead Island',
#  'Superbrothers Sword & Sworcery EP',
#  'GRID 2',
#  'Sonic & All-Stars Racing Transformed',
#  'Call of Juarez Gunslinger',
#  'Crysis 2 Maximum Edition',
#  'Strike Vector',
#  'Prison Architect',
#  'Lego Harry Potter',
#  'Outlast',
#  'Super Hexagon',
#  'WRC 4 FIA WORLD RALLY CHAMPIONSHIP',
#  'Valkyria Chronicles',
#  'Shatter',
#  'Proteus',
#  'Jamestown',
#  'Spelunky',
#  'Astebreed',
#  'STAR WARS Knights of the Old Republic II The Sith Lords',
#  'Phantom Breaker Battle Grounds',
#  "Tom Clancy's Splinter Cell Chaos Theory",
#  'The Witcher Enhanced Edition',
#  'Risk of Rain',
#  'Survarium',
#  'Afterlife Empire',
#  'BattleBlock Theater',
#  'Need for Speed Hot Pursuit',
#  'BIT.TRIP RUNNER',
#  'Coin Crypt',
#  'The Crew',
#  'Metro Last Light Redux',
#  'Crimzon Clover  WORLD IGNITION',
#  'Sonic Generations',
#  'Ethan Meteor Hunter',
#  'Reus',
#  'Kill The Bad Guy',
#  'Freaking Meatbags',
#  'Saints Row 2',
#  'Dyad',
#  'Starseed Pilgrim',
#  'Camera Obscura',
#  'The Floor is Jelly',
#  'Super Meat Boy',
#  'Dustforce',
#  'Goats on a Bridge',
#  'System Shock 2',
#  'Call of Duty Modern Warfare 2 - Multiplayer',
#  'PixelJunk Shooter',
#  'And Yet It Moves',
#  'Battlefield Bad Company 2',
#  'Cogs',
#  "Assassin's Creed IV Black Flag",
#  'SimCity 4 Deluxe',
#  'Half-Life Deathmatch Source',
#  'Call of Duty Modern Warfare 2',
#  'Rodina',
#  'Age of Empires II HD The Forgotten',
#  'Age of Empires III Complete Collection',
#  'Age of Mythology Extended Edition',
#  'Alice Madness Returns',
#  'Alien Isolation',
#  "America's Army 3",
#  "America's Army Proving Grounds",
#  'Amnesia A Machine for Pigs',
#  'Anachronox',
#  'Antichamber',
#  'Arma 2 Private Military Company',
#  'A Story About My Uncle',
#  'Audiosurf',
#  'Aveyond 3-1 Lord of Twilight',
#  'Awesomenauts',
#  'Ballpoint Universe Infinite',
#  'Beatbuddy Tale of the Guardians',
#  'Beat Hazard',
#  'BEEP',
#  'Betrayer',
#  'BlazBlue Calamity Trigger',
#  'BlazBlue Continuum Shift Extend',
#  'Blockland',
#  'Borderlands',
#  'Braid',
#  'Breach & Clear',
#  'Breath of Death VII ',
#  'Broken Age',
#  'Brothers - A Tale of Two Sons',
#  'Bulletstorm',
#  'Capsized',
#  'Castle Crashers',
#  'Child of Light',
#  'Cinders',
#  'Cities Skylines',
#  'Cloudbuilt',
#  "Command and Conquer 3 Kane's Wrath",
#  'Command and Conquer 3 Tiberium Wars',
#  'Contagion',
#  'Cook, Serve, Delicious!',
#  'Crayon Physics Deluxe',
#  'Cry of Fear',
#  'Cthulhu Saves the World ',
#  'Daikatana',
#  'Darksiders',
#  'DARK SOULS II Scholar of the First Sin',
#  'Dead Island Riptide',
#  'Deadlight',
#  'Dead Space 2',
#  'Dear Esther',
#  'Democracy 3',
#  'Deus Ex Game of the Year Edition',
#  'Deus Ex Invisible War',
#  'Deus Ex The Fall',
#  'Devil May Cry 4',
#  'DiRT 3 Complete Edition',
#  'DmC Devil May Cry',
#  'Door Kickers',
#  'Draw a Stickman EPIC',
#  'E.Y.E Divine Cybermancy',
#  'Endless Space',
#  'English Country Tune',
#  'F.E.A.R. 3',
#  'F.E.A.R. Extraction Point',
#  'F.E.A.R. Perseus Mandate',
#  'Fallen Enchantress Legendary Heroes',
#  'Fallout 3',
#  'Far Cry',
#  'FarSky',
#  'Fieldrunners 2',
#  'FINAL FANTASY III',
#  'FINAL FANTASY VIII',
#  'Finding Teddy',
#  'FRACT OSC',
#  'Galcon Fusion',
#  'GameGuru',
#  'Geometry Dash',
#  'Giana Sisters Twisted Dreams',
#  'Gigantic Army',
#  'Gods Will Be Watching',
#  'Gone Home',
#  'Gothic',
#  'Gothic 3',
#  'Gothic II Gold Edition',
#  'GRID',
#  'Guacamelee! Gold Edition',
#  'Guardians of Middle-earth',
#  'Half-Life',
#  'Half-Life 2 Deathmatch',
#  'Half-Life Source',
#  'Hammerwatch',
#  'Hero Siege',
#  'Hitman 2 Silent Assassin',
#  'Hitman Blood Money',
#  'Hitman Codename 47',
#  'Hitman Contracts',
#  'Hitman Sniper Challenge',
#  'How to Survive',
#  'I am Bread',
#  'Injustice Gods Among Us Ultimate Edition',
#  'INK - Soundtrack + Art',
#  'Ittle Dew',
#  'Jack Lumber',
#  'Just Cause',
#  'Kane & Lynch 2 Dog Days',
#  'Kerbal Space Program',
#  'Killer is Dead',
#  'Kingdoms of Amalur Reckoning',
#  'Labyrinthine Dreams',
#  'Lara Croft and the Guardian of Light',
#  'Last Word',
#  'Legends of Persia',
#  'LEGO Batman The Videogame',
#  'LEGO Harry Potter Years 5-7',
#  'LEGO MARVEL Super Heroes',
#  'LIMBO',
#  'LISA',
#  'Little Inferno',
#  'Mass Effect 2',
#  'Max Payne 3',
#  'Mechanic Escape',
#  'Mercenary Kings',
#  'METAL SLUG 3',
#  'Metro 2033 Redux',
#  'Mini Ninjas',
#  'Mitsurugi Kamui Hikae',
#  'Mortal Kombat Kollection',
#  'MURDERED SOUL SUSPECT',
#  'Need for Speed Undercover',
#  'Never Alone (Kisima Ingitchuna)',
#  'Neverending Nightmares',
#  'Nosgoth',
#  'One Way Heroics',
#  'Outland',
#  'Papers, Please',
#  'PAYDAY 2',
#  'PAYDAY The Heist',
#  "Penny Arcade's On the Rain-Slick Precipice of Darkness 3",
#  'Pixel Heroes Byte & Magic',
#  'Pixel Piracy',
#  'Polarity',
#  'POSTAL 2',
#  'Project Temporality',
#  'RAGE',
#  'Red Faction Armageddon',
#  'Red Faction Guerrilla Steam Edition',
#  'Remember Me',
#  'Remnants Of Isolation',
#  'resident evil 4 / biohazard 4',
#  'Resident Evil 5 / Biohazard 5',
#  'Resident Evil Revelations / Biohazard Revelations',
#  'Rochard',
#  'RollerCoaster Tycoon 3 Platinum!',
#  'RPG Maker VX Ace',
#  'Saints Row Gat out of Hell',
#  'Screencheat',
#  'Scribblenauts Unlimited',
#  'Shadowgrounds Survivor',
#  'Shadowrun Returns',
#  'Shadow Warrior',
#  'Shank',
#  'Sins of a Solar Empire Rebellion',
#  'Skulls of the Shogun',
#  'Sonic CD',
#  'Space Engineers',
#  'Spiral Knights',
#  'Sprite Lamp',
#  'Star Wars - Battlefront II',
#  'Star Wars Dark Forces',
#  'Star Wars Empire at War Gold',
#  'Star Wars Knights of the Old Republic',
#  'Star Wars The Force Unleashed II',
#  'Star Wars The Force Unleashed Ultimate Sith Edition',
#  'Star Wars Jedi Knight Dark Forces II',
#  'Star Wars Jedi Knight Jedi Academy',
#  'Star Wars Republic Commando',
#  'Star Wars Starfighter',
#  'Star Wars The Clone Wars Republic Heroes',
#  'State of Decay',
#  'Survivalist',
#  'Syberia',
#  'Syberia 2',
#  'Terraria',
#  "The Beginner's Guide",
#  'The Binding of Isaac Rebirth',
#  'The Cat Lady',
#  'The Incredible Adventures of Van Helsing II',
#  'The Last Remnant',
#  'The Long Dark',
#  'The Lord of the Rings War in the North',
#  'The Swapper',
#  'The Talos Principle Road To Gehenna',
#  'The Vanishing of Ethan Carter Redux',
#  'The Witcher 2 Assassins of Kings Enhanced Edition',
#  'The Witcher 3 Wild Hunt',
#  'The Wolf Among Us',
#  'Thief',
#  'Thief Gold',
#  'This War of Mine',
#  'Thomas Was Alone',
#  "Tiny and Big Grandpa's Leftovers",
#  'Titan Quest',
#  'Titan Quest Immortal Throne',
#  'Torchlight',
#  'Toribash',
#  'Total War SHOGUN 2',
#  'Transistor',
#  'TRI Of Friendship and Madness',
#  'TypeRider',
#  'Unholy Heights',
#  'Unturned',
#  'Vessel',
#  'Viscera Cleanup Detail Shadow Warrior',
#  'VVVVVV',
#  'Whisper of a Rose',
#  'Wizorb',
#  'Wrack',
#  'Ys Origin',
#  'Zen Bound 2',
#  'Strife',
#  'Call of Duty Black Ops - Multiplayer',
#  'Counter-Strike Source',
#  'Dungeon Defenders',
#  'Call of Duty Black Ops',
#  'Day of Defeat Source',
#  'ArcheAge',
#  'Empire Total War',
#  'ARK Survival Evolved',
#  'Alien Swarm',
#  'TERA',
#  'Rust',
#  'Flatout 3',
#  'Counter-Strike Nexon Zombies',
#  'Everlasting Summer',
#  'War Thunder',
#  'DCS World',
#  'Fishing Planet',
#  'Cannons Lasers Rockets',
#  'Dragon Nest Europe',
#  'Loadout',
#  'Neverwinter',
#  'No More Room in Hell',
#  'RIFT',
#  'Tactical Intervention',
#  'Warframe',
#  'Zombies Monsters Robots',
#  'Clicker Heroes',
#  'Crusaders of the Lost Idols',
#  'GASP',
#  'theHunter',
#  'Max Payne 2 The Fall of Max Payne',
#  'Mafia II',
#  'Revenge of the Titans',
#  'A Virus Named TOM',
#  'Europa Universalis III',
#  'Super Puzzle Platformer Deluxe',
#  'Painkiller Overdose',
#  '99 Levels To Hell',
#  'Adventures of Shuggy',
#  'Arma Cold War Assault',
#  'Batman Arkham Origins',
#  'Commando Jack',
#  'Cortex Command',
#  'Deadbreed',
#  'Dino D-Day',
#  'Eets Munchies',
#  'Enclave',
#  'GTR Evolution',
#  'Machinarium',
#  'RACE 07',
#  'RaceRoom Racing Experience ',
#  'Woodle Tree Adventures',
#  'X-Tension',
#  'X2 The Threat',
#  'X3 Albion Prelude',
#  'X3 Reunion',
#  'X3 Terran Conflict',
#  'X Beyond the Frontier',
#  "Tom Clancy's Ghost Recon Phantoms - NA",
#  'APB Reloaded',
#  'War Inc. Battlezone',
#  'ORION Prelude',
#  'Hotline Miami 2 Wrong Number',
#  'Deadpool',
#  'Counter-Strike Condition Zero',
#  'Counter-Strike',
#  'Counter-Strike Condition Zero Deleted Scenes',
#  'Day of Defeat',
#  'Deathmatch Classic',
#  'Ricochet',
#  'Mount & Blade Warband',
#  "Tom Clancy's Ghost Recon Phantoms - EU",
#  'SMITE',
#  'Infinite Crisis',
#  'AdVenture Capitalist',
#  'Heroes & Generals',
#  'My Lands',
#  'Archeblade',
#  'Half-Life Blue Shift',
#  'Half-Life Opposing Force',
#  'Team Fortress Classic',
#  'Project CARS',
#  'Project CARS - Modified Car Pack ',
#  'Defense Grid The Awakening',
#  'Cloud Chamber',
#  'Stacking',
#  'Ghostbusters The Video Game',
#  'Faerie Solitaire',
#  'Dreamfall Chapters',
#  'Portal Stories Mel',
#  'Universe Sandbox',
#  'Toki Tori',
#  'The Wonderful End of the World',
#  'Hacker Evolution',
#  'Costume Quest',
#  'RUSH',
#  'Return to Mysterious Island 2',
#  'World of Goo',
#  'Portal 2 - The Final Hours',
#  'AaAaAA!!! - A Reckless Disregard for Gravity',
#  'GEARCRACK Arena',
#  'Quantum Conundrum',
#  'Mission Control NanoMech',
#  "Alan Wake's American Nightmare",
#  'Sam & Max 101 Culture Shock',
#  'The Ball',
#  'Torchlight II',
#  'Sam & Max 102 Situation Comedy',
#  'Oozi Earth Adventure',
#  "Organ Trail Director's Cut",
#  'BIT.TRIP BEAT',
#  'Atom Zombie Smasher ',
#  '1... 2... 3... KICK IT! (Drop That Beat Like an Ugly Baby)',
#  'Botanicula',
#  'Ticket to Ride',
#  'Penumbra Overture',
#  'Lucid',
#  'Critical Mass',
#  'Pixel Puzzles Japan',
#  'Leviathan The Last Day of the Decade',
#  'Gish',
#  'Alien Breed 2 Assault',
#  "Amerzone The Explorer's Legacy",
#  'Aquaria',
#  'Costume Quest 2',
#  'Dead Bits',
#  'Defense Grid 2',
#  'Defy Gravity',
#  "Five Nights at Freddy's 2",
#  'Lugaru HD ',
#  'Midnight Club II',
#  "Oddworld Abe's Oddysee",
#  'Really Big Sky',
#  "Rift's Cave",
#  'RoboBlitz',
#  'Salammbo Battle for Carthage',
#  'Sam & Max 103 The Mole, the Mob and the Meatball',
#  'Sam & Max 105 Reality 2.0',
#  'Sam & Max 106 Bright Side of the Moon',
#  'Sam & Max 201 Ice Station Santa',
#  'Sam & Max 202 Moai Better Blues',
#  'Sam & Max 203 Night of the Raving Dead',
#  'Sam & Max 204 Chariots of the Dogs',
#  "Sam & Max 205 What's New Beelzebub?",
#  'Sam & Max 301 The Penal Zone',
#  'Sam & Max 302 The Tomb of Sammun-Mak',
#  "Sam & Max 303 They Stole Max's Brain!",
#  'Sam & Max 304 Beyond the Alley of the Dolls',
#  'Sam & Max 305 The City that Dares not Sleep',
#  'Samorost 2',
#  'SolForge',
#  'Steel Storm Burning Retribution',
#  'Talisman Prologue',
#  'Teleglitch Die More Edition',
#  'Ticket to Ride - Europe',
#  'BLOCKADE 3D',
#  'The Elder Scrolls IV Oblivion ',
#  "Assassin's Creed Brotherhood",
#  'The Elder Scrolls III Morrowind',
#  'Hidden Object Bundle 4 in 1',
#  'Worms Reloaded',
#  'FlatOut Ultimate Carnage',
#  'Chivalry Medieval Warfare',
#  'Ghost Master',
#  'Peggle Deluxe',
#  'Peggle Nights',
#  'Puzzler World 2',
#  'Bejeweled 3',
#  'The Book of Unwritten Tales',
#  'The Movies',
#  'The Walking Dead',
#  "MacGuffin's Curse",
#  'The Testament of Sherlock Holmes',
#  'Bully Scholarship Edition',
#  'Indigo Prophecy',
#  'Crazy Machines 2',
#  'The Secret of Monkey Island Special Edition',
#  'Deponia The Complete Journey',
#  'DiRT 2',
#  'Worms Clan Wars',
#  'Monkey Island 2 Special Edition',
#  '4 Elements',
#  'Cryostasis',
#  'TrackMania Stadium',
#  'Aura Fate of the Ages',
#  'Eets',
#  'Trials 2 Second Edition',
#  'Grim Legends The Forsaken Bride',
#  'Nightmares from the Deep 2 The Siren`s Call',
#  'Tales of Monkey Island Chapter 2 - The Siege of Spinner Cay ',
#  'The Jackbox Party Pack',
#  'Abyss The Wraiths of Eden',
#  'Anodyne',
#  'Singularity',
#  'The Maw',
#  'Poker Night at the Inventory',
#  'Penumbra Black Plague',
#  'Sinister City',
#  'Puzzle Agent',
#  'Cargo! - The quest for gravity',
#  'Rocketbirds Hardboiled Chicken',
#  'Nightmares from the Deep The Cursed Heart',
#  'Insanely Twisted Shadow Planet',
#  'Surgeon Simulator',
#  'Alchemy Mysteries Prague Legends',
#  'Clockwork Tales Of Glass and Ink',
#  'CID The Dummy',
#  'Tales of Monkey Island Chapter 4 - The Trial and Execution of Guybrush Threepwood ',
#  'Puzzle Agent 2',
#  '9 Clues The Secret of Serpent Creek',
#  'The Tiny Bang Story',
#  'Shoppe Keep',
#  'Windosill',
#  'Plants vs. Zombies Game of the Year',
#  'ibb & obb',
#  'Obulis',
#  'Chime',
#  'Sam & Max 104 Abe Lincoln Must Die!',
#  'Ben There, Dan That!',
#  'Fate of the World',
#  'Octodad Dadliest Catch',
#  'Trials Evolution Gold Edition',
#  'Penumbra Requiem',
#  'Spectraball',
#  'Plain Sight',
#  'The Cave',
#  'Just Cause 2 Multiplayer Mod',
#  'Blocks That Matter',
#  'Time Gentlemen, Please!',
#  'Trine 2',
#  'Blur',
#  "YOU DON'T KNOW JACK Vol. 1 XL",
#  'Port of Call',
#  'LEGO Worlds',
#  'Zeno Clash',
#  'FORCED',
#  'Hydrophobia Prophecy',
#  'Gravilon',
#  'The Longest Journey',
#  'Shadow Puppeteer',
#  'The Path - Prologue',
#  'The Misadventures of P.B. Winterbottom',
#  'Vertiginous Golf',
#  'EDGE',
#  'Shank 2',
#  'Jolly Rover',
#  "Sid Meier's Civilization IV",
#  'The Movies Stunts and Effects',
#  'Prince of Persia',
#  'Blue Toad Murder Files - The Mysteries of Little Riddle',
#  'Afterfall InSanity Extended Edition',
#  'AirBuccaneers',
#  'Aliens vs. Predator',
#  'Alter Ego',
#  'Always Sometimes Monsters',
#  'Anomaly Korea',
#  'Back to Bed',
#  'Beware Planet Earth',
#  'Blackwell Epiphany',
#  "Broken Sword 5 - the Serpent's Curse",
#  'Chaser',
#  'Chucks Challenge 3D',
#  'Closure',
#  'Crash Time II',
#  'Crazy Machines Elements',
#  'Damned',
#  'Darkout',
#  'Darksiders II',
#  'Deep Under the Sky',
#  'Deponia',
#  'Depth Hunter 2 Deep Dive',
#  'DETOUR',
#  'Dogfight 1942',
#  'Dogfight 1942 Russia under Siege',
#  'Dr. Langeskov, The Tiger, and The Terribly Cursed Emerald A Whirlwind Heist',
#  'Dreamfall The Longest Journey',
#  'Driver San Francisco',
#  'Duke Nukem Forever',
#  'Forge',
#  'Genesis Rising',
#  'Gravi',
#  'Greed Corp',
#  'Hard Reset',
#  'Helldorado',
#  'Homefront',
#  'Ichi',
#  'Incredipede',
#  'Iron Brigade',
#  'Jurassic Park The Game',
#  'Kane & Lynch Dead Men',
#  'Legend of Grimrock',
#  'Magicka Frozen Lake',
#  'Maia',
#  'Megabyte Punch',
#  'Men of War Condemned Heroes',
#  'Nikopol Secrets of the Immortals',
#  'Nimbus',
#  'Numen Contest of Heroes',
#  'Offspring Fling!',
#  'Papo & Yo',
#  'Pid ',
#  'Potatoman Seeks the Troof',
#  'Pressure',
#  'Primordia',
#  'Rising Storm/Red Orchestra 2 Multiplayer',
#  'Scoregasm',
#  'Secret Files Tunguska',
#  'Sideway',
#  "Sid Meier's Civilization IV Beyond the Sword",
#  "Sid Meier's Civilization IV Warlords",
#  'Snapshot',
#  'Sniper Ghost Warrior',
#  'Sniper Elite V2',
#  'SpaceChem',
#  'State of Decay - Breakdown',
#  'Still Life',
#  'STORM Frontline Nation',
#  'Supreme Commander 2',
#  'Tengami',
#  "The Bard's Tale",
#  'The Basement Collection',
#  'The Book of Unwritten Tales The Critter Chronicles',
#  'The Chronicles of Riddick Assault on Dark Athena',
#  'The Dead Linger',
#  'The Dream Machine',
#  'The Night of the Rabbit',
#  'The Novelist',
#  'The Whispered World',
#  'The Whispered World Special Edition',
#  'Tomb Raider Anniversary',
#  'Tomb Raider Chronicles',
#  'Tomb Raider Legend',
#  'Tomb Raider The Last Revelation',
#  'Tomb Raider Underworld',
#  'Tomb Raider II',
#  'Tomb Raider III Adventures of Lara Croft',
#  "Tom Clancy's Splinter Cell Conviction",
#  'Tower Wars',
#  'Towns',
#  'Toy Soldiers',
#  'Valdis Story Abyssal City',
#  'Vampire The Masquerade - Bloodlines',
#  'Wasteland Angel',
#  'Where is my Heart?',
#  'Wolfenstein',
#  'Xotic',
#  "YOU DON'T KNOW JACK HEADRUSH",
#  "YOU DON'T KNOW JACK MOVIES",
#  "YOU DON'T KNOW JACK SPORTS",
#  "YOU DON'T KNOW JACK TELEVISION",
#  "YOU DON'T KNOW JACK Vol. 2",
#  "YOU DON'T KNOW JACK Vol. 3",
#  "YOU DON'T KNOW JACK Vol. 4 The Ride",
#  'Simply Chess',
#  'H1Z1',
#  'Commandos 3 Destination Berlin',
#  'Age of Chivalry',
#  'Battlefield Bad Company 2 Vietnam',
#  'Clans',
#  'Warface',
#  'Labyronia RPG',
#  'Aftermath',
#  'Happy Wars',
#  'the static speaks my name',
#  'Pyramid Raid',
#  'Aura Kingdom',
#  'School of Dragons How to Train Your Dragon',
#  'The Way of Life Free Edition',
#  'Bad Rats',
#  'World of Guns Gun Disassembly',
#  'Quake Live',
#  'Fractured Space',
#  'Soccer Manager 2016',
#  'Fistful of Frags',
#  'Ragnarok',
#  'Ragnarok Online 2',
#  'Tribes Ascend',
#  'Velvet Assassin',
#  'Black Fire',
#  'Narcissu 1st & 2nd',
#  'Kung Fury',
#  'Mortal Kombat Komplete Edition',
#  'Call of Duty Advanced Warfare',
#  'Call of Duty Advanced Warfare - Multiplayer',
#  'Ascend Hand of Kul',
#  'Solstice Arena',
#  'Euro Truck Simulator 2',
#  'You Have to Win the Game',
#  'GunZ 2 The Second Duel',
#  'Pyroblazer',
#  'Aion',
#  'Arma 3',
#  'La Tale',
#  'Endless Sky',
#  'Amazing World',
#  'Codename CURE',
#  'Blacklight Retribution',
#  'Electric Highways',
#  'Eternal Fate',
#  'Uebergame',
#  'Curse of Mermos',
#  "Darkest Hour Europe '44-'45",
#  'Epic Cards Battle(TCG)',
#  'Gun Monkeys',
#  'Mare Nostrum',
#  'Red Orchestra Ostfront 41-45',
#  'Trove',
#  'Dizzel',
#  'R.U.S.E',
#  'Stronghold 3',
#  'R.U.S.E.',
#  'Stronghold HD',
#  'Anomaly Warzone Earth',
#  'XCOM Enemy Unknown',
#  'Free to Play',
#  'WAKFU',
#  'Starbound',
#  'PlanetSide 2',
#  'Dirty Bomb',
#  'Starbound - Unstable',
#  'Piercing Blow',
#  'UberStrike',
#  'Marvel Puzzle Quest',
#  'NARUTO SHIPPUDEN Ultimate Ninja STORM 3 Full Burst',
#  "Don't Starve",
#  'Batman Arkham City',
#  'EVE Online',
#  'DC Universe Online',
#  'Command and Conquer 4 Tiberian Twilight',
#  'Anno 2070',
#  'Chessmaster',
#  'Transformers Fall of Cybertron',
#  'Might & Magic Heroes VI',
#  'Warhammer 40,000 Dawn of War II',
#  'DEFCON',
#  'Dungeon Siege 2',
#  'Warhammer 40,000 Space Marine',
#  'The Polynomial',
#  'Achron',
#  'Halo Spartan Assault',
#  'Trapped Dead',
#  "Tom Clancy's H.A.W.X. 2",
#  'Dungeon Siege',
#  'Warhammer 40,000 Dawn of War II  Retribution',
#  'Alpha Protocol',
#  'BRINK',
#  'Crysis',
#  'Crysis Warhead',
#  'Crysis Wars',
#  'Darkspore',
#  'Deus Ex Human Revolution - The Missing Link',
#  "Don't Starve Reign of Giants",
#  'Dungeon Siege III',
#  'Grand Theft Auto',
#  'Grand Theft Auto 2',
#  'Grand Theft Auto San Andreas',
#  'Grand Theft Auto Vice City',
#  'Grand Theft Auto III',
#  'Need for Speed SHIFT',
#  'Overlord',
#  'Overlord Raising Hell',
#  'Overlord II',
#  'Perimeter 2 New Earth',
#  'Red Faction',
#  'Red Faction II',
#  'The Walking Dead Season Two',
#  "Tom Clancy's Ghost Recon Advanced Warfighter 2",
#  'Two Worlds Epic Edition',
#  'Two Worlds II',
#  'Two Worlds II Castle Defense',
#  'Panzar',
#  'Call of Duty Black Ops II - Multiplayer',
#  'Call of Duty Black Ops II',
#  'Call of Duty Black Ops II - Zombies',
#  'Heroes of Scene',
#  'Gear Up',
#  'Guns and Robots',
#  'Medieval II Total War',
#  'MechWarrior Online',
#  'HAWKEN',
#  'Startopia',
#  'Call of Duty Modern Warfare 3 - Multiplayer',
#  'Call of Duty Modern Warfare 3',
#  'Sins of a Solar Empire Trinity',
#  'Battlefield 2',
#  'Men of War',
#  'Wargame Red Dragon',
#  'Wargame European Escalation',
#  'Full Spectrum Warrior',
#  'Insurgency Modern Infantry Combat',
#  'DiRT Rally',
#  'Men of War Assault Squad 2',
#  'Full Spectrum Warrior Ten Hammers',
#  'Verdun',
#  'A Game of Thrones - Genesis',
#  'The Ship Single Player',
#  'The Ship',
#  'COH2 - The Western Front Armies US Forces',
#  'Men of War Assault Squad',
#  'Men of War Red Tide',
#  'Men of War Vietnam',
#  'Omerta - The Con Artist',
#  'Red Crucible Firestorm',
#  'XCOM Enemy Within',
#  'Tropico 5',
#  'Life Is Strange',
#  'Section 8',
#  'Killing Floor 2',
#  "Spooky's House of Jump Scares",
#  'Primal Carnage Extinction',
#  'Warhammer 40,000 Dawn of War  Dark Crusade',
#  'Warhammer 40,000 Dawn of War  Winter Assault',
#  'The Expendabros',
#  'Knights of Pen and Paper +1',
#  "King's Quest",
#  'Star Conflict',
#  'Wind of Luck Arena',
#  ...]

# %%
tfidf_vectorizer=TfidfVectorizer(lowercase=True, stop_words='english', use_idf=True)

# %%
# just send in all your docs here
fitted_vectorizer=tfidf_vectorizer.fit(data_updated)
tfidf_vectorizer_vectors=fitted_vectorizer.transform(data_updated)

# %%
results = {}
for idx, row in data.iterrows():
   similar_indices = tfidf_vectorizer_vectors[idx].argsort()[:-100:-1] 
   similar_items = [(tfidf_vectorizer_vectors[idx][i], data['game_name'][i]) for i in similar_indices] 
   results[row['id']] = similar_items[1:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-675d160ba467> in <module>
#       1 results = {}
#       2 for idx, row in data.iterrows():
# ----> 3    similar_indices = tfidf_vectorizer_vectors[idx].argsort()[:-100:-1]
#       4    similar_items = [(tfidf_vectorizer_vectors[idx][i], data['game_name'][i]) for i in similar_indices]
#       5    results[row['id']] = similar_items[1:]
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     686             return self.getnnz()
#     687         else:
# --> 688             raise AttributeError(attr + " not found")
#     689
#     690     def transpose(self, axes=None, copy=False):
#
# AttributeError: argsort not found

# %%
# get the first vector out (for the first document)
first_vector_tfidfvectorizer=tfidf_vectorizer_vectors[0]
 
# place tf-idf values in a pandas data frame
df = pd.DataFrame(first_vector_tfidfvectorizer.T.todense(), index=tfidf_vectorizer.get_feature_names(), columns=["tfidf"])
df.sort_values(by=["tfidf"],ascending=False)
# Out:
#             tfidf
# skyrim   0.264183
# scrolls  0.259900
# elder    0.256069
# virtual  0.201381
# want     0.174213
# ...           ...
# fazbear  0.000000
# faye     0.000000
# faydwer  0.000000
# favours  0.000000
# 온라인      0.000000
#
# [20891 rows x 1 columns]

# %%
tf_idf_dict = dict()
for x in range(len(all_data_processed)):
    tf_idf_dict[all_data_processed[x]] = tfidf_vectorizer_vectors[x]
tf_idf_dict
# Out:
# {'The Elder Scrolls V Skyrim': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 70 stored elements in Compressed Sparse Row format>,
#  'Fallout 4': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  'Fallout New Vegas': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Left 4 Dead 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'HuniePop': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 33 stored elements in Compressed Sparse Row format>,
#  'Path of Exile': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 93 stored elements in Compressed Sparse Row format>,
#  'Poly Bridge': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 33 stored elements in Compressed Sparse Row format>,
#  'Left 4 Dead': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 105 stored elements in Compressed Sparse Row format>,
#  'Team Fortress 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'Tomb Raider': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'The Banner Saga': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  'Dead Island Epidemic': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 50 stored elements in Compressed Sparse Row format>,
#  'BioShock Infinite': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Dragon Age Origins - Ultimate Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 136 stored elements in Compressed Sparse Row format>,
#  'SEGA Genesis & Mega Drive Classics': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  'Grand Theft Auto IV': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'Realm of the Mad God': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Marvel Heroes 2015': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37 stored elements in Compressed Sparse Row format>,
#  'Eldevin': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 50 stored elements in Compressed Sparse Row format>,
#  'Dota 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 42 stored elements in Compressed Sparse Row format>,
#  'BioShock': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'Robocraft': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  "Garry's Mod": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 44 stored elements in Compressed Sparse Row format>,
#  'Jazzpunk': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'Alan Wake': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 55 stored elements in Compressed Sparse Row format>,
#  'BioShock 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'Fallen Earth': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26 stored elements in Compressed Sparse Row format>,
#  "Fallout New Vegas Courier's Stash": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 38 stored elements in Compressed Sparse Row format>,
#  'Fallout New Vegas Dead Money': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'Fallout New Vegas Honest Hearts': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Grand Theft Auto Episodes from Liberty City': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  'Hitman Absolution': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 46 stored elements in Compressed Sparse Row format>,
#  'The Elder Scrolls V Skyrim - Dawnguard': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 70 stored elements in Compressed Sparse Row format>,
#  'The Elder Scrolls V Skyrim - Dragonborn': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 70 stored elements in Compressed Sparse Row format>,
#  'The Elder Scrolls V Skyrim - Hearthfire': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 70 stored elements in Compressed Sparse Row format>,
#  'Ultra Street Fighter IV': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'FINAL FANTASY XIII': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 55 stored elements in Compressed Sparse Row format>,
#  "Sid Meier's Civilization V": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 79 stored elements in Compressed Sparse Row format>,
#  'L.A. Noire': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 105 stored elements in Compressed Sparse Row format>,
#  'Company of Heroes Tales of Valor': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  '7 Days to Die': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 125 stored elements in Compressed Sparse Row format>,
#  'Divekick': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'FINAL FANTASY VII': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Orcs Must Die! 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 57 stored elements in Compressed Sparse Row format>,
#  'Killing Floor': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'Company of Heroes': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  'Bastion': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Undertale': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'Counter-Strike Global Offensive': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 33 stored elements in Compressed Sparse Row format>,
#  'Orcs Must Die!': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'THE KING OF FIGHTERS XIII STEAM EDITION': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 195 stored elements in Compressed Sparse Row format>,
#  'GUILTY GEAR XX ACCENT CORE PLUS R': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  'Skullgirls': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 44 stored elements in Compressed Sparse Row format>,
#  "Assassin's Creed II": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Company of Heroes Opposing Fronts': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 38 stored elements in Compressed Sparse Row format>,
#  'Guilty Gear X2 #Reload': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Psychonauts': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  'Company of Heroes 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'Magicka': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 51 stored elements in Compressed Sparse Row format>,
#  'Magicka Vietnam': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Natural Selection 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Sanctum': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28 stored elements in Compressed Sparse Row format>,
#  'Sanctum 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'Serious Sam 3 BFE': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Grand Theft Auto V': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Insurgency': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'METAL GEAR SOLID V THE PHANTOM PAIN': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'S.T.A.L.K.E.R. Shadow of Chernobyl': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 62 stored elements in Compressed Sparse Row format>,
#  'S.T.A.L.K.E.R. Call of Pripyat': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 62 stored elements in Compressed Sparse Row format>,
#  'Saints Row The Third': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'Far Cry 3': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'S.T.A.L.K.E.R. Clear Sky': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 86 stored elements in Compressed Sparse Row format>,
#  'Rocket League': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 53 stored elements in Compressed Sparse Row format>,
#  'Far Cry 4': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Prototype': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Space Pirates and Zombies': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'Dying Light': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 41 stored elements in Compressed Sparse Row format>,
#  'Just Cause 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  "Mirror's Edge": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 46 stored elements in Compressed Sparse Row format>,
#  'Mad Max': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 116 stored elements in Compressed Sparse Row format>,
#  'Portal 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Deus Ex Human Revolution': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 55 stored elements in Compressed Sparse Row format>,
#  'Middle-earth Shadow of Mordor': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 98 stored elements in Compressed Sparse Row format>,
#  'RUNNING WITH RIFLES': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 78 stored elements in Compressed Sparse Row format>,
#  'Tropico 4': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Cave Story+': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  'Dust An Elysian Tail': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 58 stored elements in Compressed Sparse Row format>,
#  'F.E.A.R.': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 61 stored elements in Compressed Sparse Row format>,
#  'South Park The Stick of Truth': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 87 stored elements in Compressed Sparse Row format>,
#  'Sleeping Dogs': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 42 stored elements in Compressed Sparse Row format>,
#  'Watch_Dogs': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'Saints Row IV': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'DayZ': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 51 stored elements in Compressed Sparse Row format>,
#  'Half-Life 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  'Reassembly': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  "Sid Meier's Civilization III Complete": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'The Talos Principle': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  'DiRT 3': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  'FTL Faster Than Light': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'Age of Empires II HD Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 50 stored elements in Compressed Sparse Row format>,
#  'Batman Arkham Asylum GOTY Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  'Gunpoint': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 47 stored elements in Compressed Sparse Row format>,
#  'Rebuild 3 Gangs of Deadsville': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37 stored elements in Compressed Sparse Row format>,
#  "Recettear An Item Shop's Tale": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Metro 2033': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 75 stored elements in Compressed Sparse Row format>,
#  'Monaco': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 59 stored elements in Compressed Sparse Row format>,
#  'Overgrowth': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  "Assassin's Creed III": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 56 stored elements in Compressed Sparse Row format>,
#  'Ori and the Blind Forest': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 82 stored elements in Compressed Sparse Row format>,
#  'Far Cry 3 Blood Dragon': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 44 stored elements in Compressed Sparse Row format>,
#  'Burnout Paradise The Ultimate Box': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'PROTOTYPE 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'Game Dev Tycoon': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26 stored elements in Compressed Sparse Row format>,
#  'Sniper Elite 3': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 68 stored elements in Compressed Sparse Row format>,
#  'Gratuitous Space Battles': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  'Rogue Legacy': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28 stored elements in Compressed Sparse Row format>,
#  'Plague Inc Evolved': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'From Dust': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35 stored elements in Compressed Sparse Row format>,
#  'Next Car Game Wreckfest': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 49 stored elements in Compressed Sparse Row format>,
#  'Rivals of Aether': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Half-Life 2 Episode Two': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  'Rise of Nations Extended Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'Nidhogg': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  'Spec Ops The Line': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Dishonored': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35 stored elements in Compressed Sparse Row format>,
#  'Half-Life 2 Episode One': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  'Wolfenstein The New Order': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 70 stored elements in Compressed Sparse Row format>,
#  'Distance': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 128 stored elements in Compressed Sparse Row format>,
#  'Epic Battle Fantasy 4': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28 stored elements in Compressed Sparse Row format>,
#  'Metro Last Light': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Miasmata': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Dead Space': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'Hotline Miami': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28 stored elements in Compressed Sparse Row format>,
#  'NOT A HERO': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28 stored elements in Compressed Sparse Row format>,
#  'Receiver': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'Crypt of the NecroDancer': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  'Portal': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'F.E.A.R. 2 Project Origin': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'NaissanceE': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 123 stored elements in Compressed Sparse Row format>,
#  'SteamWorld Dig': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 106 stored elements in Compressed Sparse Row format>,
#  'Kairo': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'The Binding of Isaac': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 65 stored elements in Compressed Sparse Row format>,
#  'LEGO The Lord of the Rings': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 78 stored elements in Compressed Sparse Row format>,
#  'METAL GEAR RISING REVENGEANCE': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 99 stored elements in Compressed Sparse Row format>,
#  'Starpoint Gemini 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  'The Vanishing of Ethan Carter': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'Goat Simulator': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 72 stored elements in Compressed Sparse Row format>,
#  'Mass Effect': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 131 stored elements in Compressed Sparse Row format>,
#  'Arma 2 Operation Arrowhead': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 67 stored elements in Compressed Sparse Row format>,
#  'METAL GEAR SOLID V GROUND ZEROES': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 66 stored elements in Compressed Sparse Row format>,
#  'Banished': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'DiRT Showdown': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35 stored elements in Compressed Sparse Row format>,
#  'Sonic Adventure 2 ': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'Battlestations Midway': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  'HOARD': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  'Sunless Sea': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  'Mark of the Ninja': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 47 stored elements in Compressed Sparse Row format>,
#  'Creeper World 3 Arc Eternal': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'Turbo Dismount': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 58 stored elements in Compressed Sparse Row format>,
#  'Floating Point': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 54 stored elements in Compressed Sparse Row format>,
#  'Grow Home': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'LUFTRAUSERS': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Arma 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 52 stored elements in Compressed Sparse Row format>,
#  'No Time To Explain Remastered': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  'FEZ': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 44 stored elements in Compressed Sparse Row format>,
#  'Delver': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 42 stored elements in Compressed Sparse Row format>,
#  'The Legend of Heroes Trails in the Sky': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 98 stored elements in Compressed Sparse Row format>,
#  'Evoland': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'Bleed': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'Borderlands 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Race The Sun': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 58 stored elements in Compressed Sparse Row format>,
#  'Shadowgrounds': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31 stored elements in Compressed Sparse Row format>,
#  'They Bleed Pixels': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 57 stored elements in Compressed Sparse Row format>,
#  'Trine': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Sir, You Are Being Hunted': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  'Symphony': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 64 stored elements in Compressed Sparse Row format>,
#  'DLC Quest': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Far Cry 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'The Stanley Parable': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'Freedom Planet': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 56 stored elements in Compressed Sparse Row format>,
#  'KHOLAT': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 61 stored elements in Compressed Sparse Row format>,
#  'Osmos': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'Oil Rush': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'Unepic': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'The Legend of Korra': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 38 stored elements in Compressed Sparse Row format>,
#  '404Sight': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'Dark Souls Prepare to Die Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  'Gravity Ghost': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'Rock of Ages': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 41 stored elements in Compressed Sparse Row format>,
#  'Half-Life 2 Lost Coast': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  'Galcon Legends': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Air Brawl': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  'Cat Goes Fishing': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'One Finger Death Punch': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 68 stored elements in Compressed Sparse Row format>,
#  'Mind Path to Thalamus Enhanced Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  'Intrusion 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'Amnesia The Dark Descent': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Fieldrunners': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'Out There Somewhere': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  'KAMI': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  "Lone Survivor The Director's Cut": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'NightSky': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'Frozen Synapse': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 64 stored elements in Compressed Sparse Row format>,
#  'Hammerfight': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31 stored elements in Compressed Sparse Row format>,
#  'Spintires': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'Ziggurat': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 70 stored elements in Compressed Sparse Row format>,
#  'AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 66 stored elements in Compressed Sparse Row format>,
#  'Dead Island': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 81 stored elements in Compressed Sparse Row format>,
#  'Superbrothers Sword & Sworcery EP': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'GRID 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'Sonic & All-Stars Racing Transformed': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'Call of Juarez Gunslinger': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Crysis 2 Maximum Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  'Strike Vector': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28 stored elements in Compressed Sparse Row format>,
#  'Prison Architect': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Lego Harry Potter': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  'Outlast': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'Super Hexagon': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  'WRC 4 FIA WORLD RALLY CHAMPIONSHIP': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Valkyria Chronicles': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26 stored elements in Compressed Sparse Row format>,
#  'Shatter': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  'Proteus': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Jamestown': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Spelunky': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 49 stored elements in Compressed Sparse Row format>,
#  'Astebreed': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 58 stored elements in Compressed Sparse Row format>,
#  'STAR WARS Knights of the Old Republic II The Sith Lords': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Phantom Breaker Battle Grounds': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  "Tom Clancy's Splinter Cell Chaos Theory": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'The Witcher Enhanced Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  'Risk of Rain': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 69 stored elements in Compressed Sparse Row format>,
#  'Survarium': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 47 stored elements in Compressed Sparse Row format>,
#  'Afterlife Empire': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'BattleBlock Theater': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 154 stored elements in Compressed Sparse Row format>,
#  'Need for Speed Hot Pursuit': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  'BIT.TRIP RUNNER': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31 stored elements in Compressed Sparse Row format>,
#  'Coin Crypt': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  'The Crew': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Metro Last Light Redux': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 152 stored elements in Compressed Sparse Row format>,
#  'Crimzon Clover  WORLD IGNITION': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 154 stored elements in Compressed Sparse Row format>,
#  'Sonic Generations': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 45 stored elements in Compressed Sparse Row format>,
#  'Ethan Meteor Hunter': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 60 stored elements in Compressed Sparse Row format>,
#  'Reus': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26 stored elements in Compressed Sparse Row format>,
#  'Kill The Bad Guy': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'Freaking Meatbags': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 87 stored elements in Compressed Sparse Row format>,
#  'Saints Row 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Dyad': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'Starseed Pilgrim': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'Camera Obscura': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'The Floor is Jelly': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 38 stored elements in Compressed Sparse Row format>,
#  'Super Meat Boy': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 169 stored elements in Compressed Sparse Row format>,
#  'Dustforce': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  'Goats on a Bridge': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 63 stored elements in Compressed Sparse Row format>,
#  'System Shock 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'Call of Duty Modern Warfare 2 - Multiplayer': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37 stored elements in Compressed Sparse Row format>,
#  'PixelJunk Shooter': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 52 stored elements in Compressed Sparse Row format>,
#  'And Yet It Moves': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 33 stored elements in Compressed Sparse Row format>,
#  'Battlefield Bad Company 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 58 stored elements in Compressed Sparse Row format>,
#  'Cogs': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  "Assassin's Creed IV Black Flag": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'SimCity 4 Deluxe': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Half-Life Deathmatch Source': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  'Call of Duty Modern Warfare 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37 stored elements in Compressed Sparse Row format>,
#  'Rodina': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'Age of Empires II HD The Forgotten': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 41 stored elements in Compressed Sparse Row format>,
#  'Age of Empires III Complete Collection': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  'Age of Mythology Extended Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35 stored elements in Compressed Sparse Row format>,
#  'Alice Madness Returns': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  'Alien Isolation': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 51 stored elements in Compressed Sparse Row format>,
#  "America's Army 3": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 60 stored elements in Compressed Sparse Row format>,
#  "America's Army Proving Grounds": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Amnesia A Machine for Pigs': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  'Anachronox': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'Antichamber': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 40 stored elements in Compressed Sparse Row format>,
#  'Arma 2 Private Military Company': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'A Story About My Uncle': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 42 stored elements in Compressed Sparse Row format>,
#  'Audiosurf': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Aveyond 3-1 Lord of Twilight': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 125 stored elements in Compressed Sparse Row format>,
#  'Awesomenauts': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  'Ballpoint Universe Infinite': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'Beatbuddy Tale of the Guardians': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 97 stored elements in Compressed Sparse Row format>,
#  'Beat Hazard': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 64 stored elements in Compressed Sparse Row format>,
#  'BEEP': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Betrayer': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'BlazBlue Calamity Trigger': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 41 stored elements in Compressed Sparse Row format>,
#  'BlazBlue Continuum Shift Extend': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'Blockland': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26 stored elements in Compressed Sparse Row format>,
#  'Borderlands': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  'Braid': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 52 stored elements in Compressed Sparse Row format>,
#  'Breach & Clear': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 45 stored elements in Compressed Sparse Row format>,
#  'Breath of Death VII ': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  'Broken Age': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 65 stored elements in Compressed Sparse Row format>,
#  'Brothers - A Tale of Two Sons': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 65 stored elements in Compressed Sparse Row format>,
#  'Bulletstorm': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 90 stored elements in Compressed Sparse Row format>,
#  'Capsized': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'Castle Crashers': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35 stored elements in Compressed Sparse Row format>,
#  'Child of Light': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  'Cinders': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  'Cities Skylines': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 54 stored elements in Compressed Sparse Row format>,
#  'Cloudbuilt': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  "Command and Conquer 3 Kane's Wrath": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 75 stored elements in Compressed Sparse Row format>,
#  'Command and Conquer 3 Tiberium Wars': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 228 stored elements in Compressed Sparse Row format>,
#  'Contagion': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 51 stored elements in Compressed Sparse Row format>,
#  'Cook, Serve, Delicious!': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  'Crayon Physics Deluxe': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'Cry of Fear': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26 stored elements in Compressed Sparse Row format>,
#  'Cthulhu Saves the World ': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Daikatana': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Darksiders': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 44 stored elements in Compressed Sparse Row format>,
#  'DARK SOULS II Scholar of the First Sin': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  'Dead Island Riptide': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'Deadlight': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35 stored elements in Compressed Sparse Row format>,
#  'Dead Space 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2 stored elements in Compressed Sparse Row format>,
#  'Dear Esther': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  'Democracy 3': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 47 stored elements in Compressed Sparse Row format>,
#  'Deus Ex Game of the Year Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Deus Ex Invisible War': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 49 stored elements in Compressed Sparse Row format>,
#  'Deus Ex The Fall': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Devil May Cry 4': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 56 stored elements in Compressed Sparse Row format>,
#  'DiRT 3 Complete Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 45 stored elements in Compressed Sparse Row format>,
#  'DmC Devil May Cry': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Door Kickers': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 57 stored elements in Compressed Sparse Row format>,
#  'Draw a Stickman EPIC': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  'E.Y.E Divine Cybermancy': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  'Endless Space': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28 stored elements in Compressed Sparse Row format>,
#  'English Country Tune': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'F.E.A.R. 3': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 40 stored elements in Compressed Sparse Row format>,
#  'F.E.A.R. Extraction Point': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26 stored elements in Compressed Sparse Row format>,
#  'F.E.A.R. Perseus Mandate': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Fallen Enchantress Legendary Heroes': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31 stored elements in Compressed Sparse Row format>,
#  'Fallout 3': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 67 stored elements in Compressed Sparse Row format>,
#  'Far Cry': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'FarSky': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Fieldrunners 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'FINAL FANTASY III': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  'FINAL FANTASY VIII': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'Finding Teddy': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 111 stored elements in Compressed Sparse Row format>,
#  'FRACT OSC': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Galcon Fusion': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  'GameGuru': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  'Geometry Dash': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  'Giana Sisters Twisted Dreams': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 49 stored elements in Compressed Sparse Row format>,
#  'Gigantic Army': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 57 stored elements in Compressed Sparse Row format>,
#  'Gods Will Be Watching': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 55 stored elements in Compressed Sparse Row format>,
#  'Gone Home': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 46 stored elements in Compressed Sparse Row format>,
#  'Gothic': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
# ...
#  'Mare Nostrum': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3 stored elements in Compressed Sparse Row format>,
#  'Red Orchestra Ostfront 41-45': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 63 stored elements in Compressed Sparse Row format>,
#  'Trove': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Dizzel': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  'R.U.S.E': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 59 stored elements in Compressed Sparse Row format>,
#  'Stronghold 3': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 42 stored elements in Compressed Sparse Row format>,
#  'R.U.S.E.': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 59 stored elements in Compressed Sparse Row format>,
#  'Stronghold HD': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 82 stored elements in Compressed Sparse Row format>,
#  'Anomaly Warzone Earth': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 100 stored elements in Compressed Sparse Row format>,
#  'XCOM Enemy Unknown': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 57 stored elements in Compressed Sparse Row format>,
#  'Free to Play': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'WAKFU': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 33 stored elements in Compressed Sparse Row format>,
#  'Starbound': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'PlanetSide 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 40 stored elements in Compressed Sparse Row format>,
#  'Dirty Bomb': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'Starbound - Unstable': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'Piercing Blow': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'UberStrike': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  'Marvel Puzzle Quest': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 41 stored elements in Compressed Sparse Row format>,
#  'NARUTO SHIPPUDEN Ultimate Ninja STORM 3 Full Burst': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 79 stored elements in Compressed Sparse Row format>,
#  "Don't Starve": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 42 stored elements in Compressed Sparse Row format>,
#  'Batman Arkham City': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'EVE Online': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 49 stored elements in Compressed Sparse Row format>,
#  'DC Universe Online': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 51 stored elements in Compressed Sparse Row format>,
#  'Command and Conquer 4 Tiberian Twilight': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 143 stored elements in Compressed Sparse Row format>,
#  'Anno 2070': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24 stored elements in Compressed Sparse Row format>,
#  'Chessmaster': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 56 stored elements in Compressed Sparse Row format>,
#  'Transformers Fall of Cybertron': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  'Might & Magic Heroes VI': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'Warhammer 40,000 Dawn of War II': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26 stored elements in Compressed Sparse Row format>,
#  'DEFCON': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 53 stored elements in Compressed Sparse Row format>,
#  'Dungeon Siege 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 104 stored elements in Compressed Sparse Row format>,
#  'Warhammer 40,000 Space Marine': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'The Polynomial': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 55 stored elements in Compressed Sparse Row format>,
#  'Achron': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Halo Spartan Assault': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37 stored elements in Compressed Sparse Row format>,
#  'Trapped Dead': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 83 stored elements in Compressed Sparse Row format>,
#  "Tom Clancy's H.A.W.X. 2": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 61 stored elements in Compressed Sparse Row format>,
#  'Dungeon Siege': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 50 stored elements in Compressed Sparse Row format>,
#  'Warhammer 40,000 Dawn of War II  Retribution': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'Alpha Protocol': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'BRINK': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Crysis': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'Crysis Warhead': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Crysis Wars': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Darkspore': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 75 stored elements in Compressed Sparse Row format>,
#  'Deus Ex Human Revolution - The Missing Link': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  "Don't Starve Reign of Giants": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'Dungeon Siege III': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 50 stored elements in Compressed Sparse Row format>,
#  'Grand Theft Auto': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  'Grand Theft Auto 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Grand Theft Auto San Andreas': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Grand Theft Auto Vice City': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 40 stored elements in Compressed Sparse Row format>,
#  'Grand Theft Auto III': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 75 stored elements in Compressed Sparse Row format>,
#  'Need for Speed SHIFT': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 69 stored elements in Compressed Sparse Row format>,
#  'Overlord': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48 stored elements in Compressed Sparse Row format>,
#  'Overlord Raising Hell': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'Overlord II': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 41 stored elements in Compressed Sparse Row format>,
#  'Perimeter 2 New Earth': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 63 stored elements in Compressed Sparse Row format>,
#  'Red Faction': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 150 stored elements in Compressed Sparse Row format>,
#  'Red Faction II': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 150 stored elements in Compressed Sparse Row format>,
#  'The Walking Dead Season Two': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  "Tom Clancy's Ghost Recon Advanced Warfighter 2": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 70 stored elements in Compressed Sparse Row format>,
#  'Two Worlds Epic Edition': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36 stored elements in Compressed Sparse Row format>,
#  'Two Worlds II': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  'Two Worlds II Castle Defense': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 78 stored elements in Compressed Sparse Row format>,
#  'Panzar': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32 stored elements in Compressed Sparse Row format>,
#  'Call of Duty Black Ops II - Multiplayer': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'Call of Duty Black Ops II': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'Call of Duty Black Ops II - Zombies': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'Heroes of Scene': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18 stored elements in Compressed Sparse Row format>,
#  'Gear Up': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23 stored elements in Compressed Sparse Row format>,
#  'Guns and Robots': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35 stored elements in Compressed Sparse Row format>,
#  'Medieval II Total War': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 82 stored elements in Compressed Sparse Row format>,
#  'MechWarrior Online': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22 stored elements in Compressed Sparse Row format>,
#  'HAWKEN': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34 stored elements in Compressed Sparse Row format>,
#  'Startopia': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 82 stored elements in Compressed Sparse Row format>,
#  'Call of Duty Modern Warfare 3 - Multiplayer': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'Call of Duty Modern Warfare 3': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'Sins of a Solar Empire Trinity': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43 stored elements in Compressed Sparse Row format>,
#  'Battlefield 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 41 stored elements in Compressed Sparse Row format>,
#  'Men of War': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 89 stored elements in Compressed Sparse Row format>,
#  'Wargame Red Dragon': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  'Wargame European Escalation': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 52 stored elements in Compressed Sparse Row format>,
#  'Full Spectrum Warrior': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  'Insurgency Modern Infantry Combat': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 57 stored elements in Compressed Sparse Row format>,
#  'DiRT Rally': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  'Men of War Assault Squad 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37 stored elements in Compressed Sparse Row format>,
#  'Full Spectrum Warrior Ten Hammers': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 61 stored elements in Compressed Sparse Row format>,
#  'Verdun': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'A Game of Thrones - Genesis': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30 stored elements in Compressed Sparse Row format>,
#  'The Ship Single Player': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  'The Ship': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  'COH2 - The Western Front Armies US Forces': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31 stored elements in Compressed Sparse Row format>,
#  'Men of War Assault Squad': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 73 stored elements in Compressed Sparse Row format>,
#  'Men of War Red Tide': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  'Men of War Vietnam': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 90 stored elements in Compressed Sparse Row format>,
#  'Omerta - The Con Artist': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 80 stored elements in Compressed Sparse Row format>,
#  'Red Crucible Firestorm': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19 stored elements in Compressed Sparse Row format>,
#  'XCOM Enemy Within': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37 stored elements in Compressed Sparse Row format>,
#  'Tropico 5': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39 stored elements in Compressed Sparse Row format>,
#  'Life Is Strange': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31 stored elements in Compressed Sparse Row format>,
#  'Section 8': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29 stored elements in Compressed Sparse Row format>,
#  'Killing Floor 2': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25 stored elements in Compressed Sparse Row format>,
#  "Spooky's House of Jump Scares": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  'Primal Carnage Extinction': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31 stored elements in Compressed Sparse Row format>,
#  'Warhammer 40,000 Dawn of War  Dark Crusade': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 105 stored elements in Compressed Sparse Row format>,
#  'Warhammer 40,000 Dawn of War  Winter Assault': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 116 stored elements in Compressed Sparse Row format>,
#  'The Expendabros': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 52 stored elements in Compressed Sparse Row format>,
#  'Knights of Pen and Paper +1': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  "King's Quest": <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 57 stored elements in Compressed Sparse Row format>,
#  'Star Conflict': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27 stored elements in Compressed Sparse Row format>,
#  'Wind of Luck Arena': <1x20891 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  ...}

# %%
tf_idf_dict_pandas = pd.DataFrame(list(tf_idf_dict.items()), columns=['Game Name', 'tf_idf vector'])
tf_idf_dict_pandas
# Out:
#                                 Game Name  \
# 0              The Elder Scrolls V Skyrim
# 1                               Fallout 4
# 2                       Fallout New Vegas
# 3                           Left 4 Dead 2
# 4                                HuniePop
# ...                                   ...
# 4204                      The Bug Butcher
# 4205                   Warriors & Castles
# 4206  Romance of the Three Kingdoms Maker
# 4207                         Space Colony
# 4208                    Executive Assault
#
#                                           tf_idf vector
# 0       (0, 20730)\t0.08226313359032639\n  (0, 20585...
# 1       (0, 20585)\t0.1766533605040369\n  (0, 20484)...
# 2       (0, 20473)\t0.1774632027598725\n  (0, 20361)...
# 3       (0, 20839)\t0.1005894584704967\n  (0, 20286)...
# 4       (0, 20554)\t0.20294699632970287\n  (0, 20542...
# ...                                                 ...
# 4204    (0, 20433)\t0.07695517854501853\n  (0, 20303...
# 4205    (0, 20233)\t0.17794732411828398\n  (0, 19523...
# 4206    (0, 19223)\t0.14251235047885408\n  (0, 18782...
# 4207    (0, 18741)\t0.08907896312244576\n  (0, 18656...
# 4208    (0, 19533)\t0.26137181467254106\n  (0, 18741...
#
# [4209 rows x 2 columns]

# %%
tfidf_vectorizer_vectors.shape
# Out:
# (4209, 20891)

# %%
cos = cosine_similarity(tfidf_vectorizer_vectors, tfidf_vectorizer_vectors)
cos
# Out:
# array([[1.        , 0.32801552, 0.00495592, ..., 0.02083611, 0.0192287 ,
#         0.00594738],
#        [0.32801552, 1.        , 0.        , ..., 0.04118646, 0.0757503 ,
#         0.01258519],
#        [0.00495592, 0.        , 1.        , ..., 0.        , 0.        ,
#         0.01755842],
#        ...,
#        [0.02083611, 0.04118646, 0.        , ..., 1.        , 0.04982168,
#         0.00269423],
#        [0.0192287 , 0.0757503 , 0.        , ..., 0.04982168, 1.        ,
#         0.10254166],
#        [0.00594738, 0.01258519, 0.01755842, ..., 0.00269423, 0.10254166,
#         1.        ]])

# %%
type(cos)
# Out:
# numpy.ndarray

# %%
cos.shape
# Out:
# (4209, 4209)

# %% [markdown]
# Idea:<br> No need to use the cosine similiraty matrix that was created. <br> Instead for each player we want to recommend: <br>
# 1. Take each game vector tf-idf * log(Playing time)
# 2. Sum all the games to one vector
# 3. Do cosine similiraty with all other games.
# 4. Return recommendations.

# %%
game_purchase = pd.read_csv('steamData/game_purchase.dat',delimiter='\t')
game_purchase
# Out:
#         User_ID  Game_ID  Purchase
# 0             1        1       1.0
# 1             1        2       1.0
# 2             1        3       1.0
# 3             1        4       1.0
# 4             1        5       1.0
# ...         ...      ...       ...
# 129506    12393       29       1.0
# 129507    12393     1828       1.0
# 129508    12393     2049       1.0
# 129509    12393     1073       1.0
# 129510    12393      644       1.0
#
# [129511 rows x 3 columns]

# %%
game_play = pd.read_csv('steamData/game_play.dat',delimiter='\t')
game_play
# Out:
#        User_ID  Game_ID  Hours
# 0            1        1  273.0
# 1            1        2   87.0
# 2            1        3   14.9
# 3            1        4   12.1
# 4            1        5    8.9
# ...        ...      ...    ...
# 70484    12393       29    2.4
# 70485    12393     1828    2.2
# 70486    12393     2049    1.5
# 70487    12393     1073    1.5
# 70488    12393      644    1.4
#
# [70489 rows x 3 columns]

# %%
item_info = pd.read_csv('steamData/item_info.dat',delimiter='\t')
item_info
# Out:
#       Game_ID                            Game Name
# 0           1           The Elder Scrolls V Skyrim
# 1           2                            Fallout 4
# 2           3                                Spore
# 3           4                    Fallout New Vegas
# 4           5                        Left 4 Dead 2
# ...       ...                                  ...
# 5150     5151                   Warriors & Castles
# 5151     5152  Romance of the Three Kingdoms Maker
# 5152     5153                         Space Colony
# 5153     5154                         Life is Hard
# 5154     5155                    Executive Assault
#
# [5155 rows x 2 columns]

# %%
tf_idf_dict_pandas_merge = tf_idf_dict_pandas.merge(item_info, how='inner')
tf_idf_dict_pandas_merge
# Out:
#                                 Game Name  \
# 0              The Elder Scrolls V Skyrim
# 1                               Fallout 4
# 2                       Fallout New Vegas
# 3                           Left 4 Dead 2
# 4                                HuniePop
# ...                                   ...
# 4204                      The Bug Butcher
# 4205                   Warriors & Castles
# 4206  Romance of the Three Kingdoms Maker
# 4207                         Space Colony
# 4208                    Executive Assault
#
#                                           tf_idf vector  Game_ID
# 0       (0, 20730)\t0.08226313359032639\n  (0, 20585...        1
# 1       (0, 20585)\t0.1766533605040369\n  (0, 20484)...        2
# 2       (0, 20473)\t0.1774632027598725\n  (0, 20361)...        4
# 3       (0, 20839)\t0.1005894584704967\n  (0, 20286)...        5
# 4       (0, 20554)\t0.20294699632970287\n  (0, 20542...        6
# ...                                                 ...      ...
# 4204    (0, 20433)\t0.07695517854501853\n  (0, 20303...     5150
# 4205    (0, 20233)\t0.17794732411828398\n  (0, 19523...     5151
# 4206    (0, 19223)\t0.14251235047885408\n  (0, 18782...     5152
# 4207    (0, 18741)\t0.08907896312244576\n  (0, 18656...     5153
# 4208    (0, 19533)\t0.26137181467254106\n  (0, 18741...     5155
#
# [4209 rows x 3 columns]

# %%
User_ID = 1
specific_user_purchase = game_purchase[game_purchase.User_ID == User_ID]
specific_user_game_play = game_play[game_play.User_ID == User_ID]
specific_user_purchase
# Out:
#     User_ID  Game_ID  Purchase
# 0         1        1       1.0
# 1         1        2       1.0
# 2         1        3       1.0
# 3         1        4       1.0
# 4         1        5       1.0
# 5         1        6       1.0
# 6         1        7       1.0
# 7         1        8       1.0
# 8         1        9       1.0
# 9         1       10       1.0
# 10        1       11       1.0
# 11        1       12       1.0
# 12        1       13       1.0
# 13        1       14       1.0
# 14        1       15       1.0
# 15        1       16       1.0
# 16        1       17       1.0
# 17        1       18       1.0
# 18        1       19       1.0
# 19        1       20       1.0
# 20        1       21       1.0
# 21        1       22       1.0
# 22        1       23       1.0
# 23        1       24       1.0
# 24        1       25       1.0
# 25        1       26       1.0
# 26        1       27       1.0
# 27        1       28       1.0
# 28        1       29       1.0
# 29        1       30       1.0
# 30        1       31       1.0
# 31        1       32       1.0
# 32        1       33       1.0
# 33        1       34       1.0
# 34        1       35       1.0
# 35        1       36       1.0
# 36        1       37       1.0
# 37        1       38       1.0
# 38        1       39       1.0
# 39        1       40       1.0

# %%
specific_user_id_name_vector = specific_user_purchase.merge(tf_idf_dict_pandas_merge, on='Game_ID')
specific_user_id_name_vector
# Out:
#     User_ID  Game_ID  Purchase                                    Game Name  \
# 0         1        1       1.0                   The Elder Scrolls V Skyrim
# 1         1        2       1.0                                    Fallout 4
# 2         1        4       1.0                            Fallout New Vegas
# 3         1        5       1.0                                Left 4 Dead 2
# 4         1        6       1.0                                     HuniePop
# 5         1        7       1.0                                Path of Exile
# 6         1        8       1.0                                  Poly Bridge
# 7         1        9       1.0                                  Left 4 Dead
# 8         1       10       1.0                              Team Fortress 2
# 9         1       11       1.0                                  Tomb Raider
# 10        1       12       1.0                              The Banner Saga
# 11        1       13       1.0                         Dead Island Epidemic
# 12        1       14       1.0                            BioShock Infinite
# 13        1       15       1.0        Dragon Age Origins - Ultimate Edition
# 14        1       17       1.0           SEGA Genesis & Mega Drive Classics
# 15        1       18       1.0                          Grand Theft Auto IV
# 16        1       19       1.0                         Realm of the Mad God
# 17        1       20       1.0                           Marvel Heroes 2015
# 18        1       21       1.0                                      Eldevin
# 19        1       22       1.0                                       Dota 2
# 20        1       23       1.0                                     BioShock
# 21        1       24       1.0                                    Robocraft
# 22        1       25       1.0                                  Garry's Mod
# 23        1       26       1.0                                     Jazzpunk
# 24        1       27       1.0                                    Alan Wake
# 25        1       28       1.0                                   BioShock 2
# 26        1       29       1.0                                 Fallen Earth
# 27        1       30       1.0            Fallout New Vegas Courier's Stash
# 28        1       31       1.0                 Fallout New Vegas Dead Money
# 29        1       32       1.0              Fallout New Vegas Honest Hearts
# 30        1       33       1.0  Grand Theft Auto Episodes from Liberty City
# 31        1       34       1.0                            Hitman Absolution
# 32        1       38       1.0       The Elder Scrolls V Skyrim - Dawnguard
# 33        1       39       1.0      The Elder Scrolls V Skyrim - Dragonborn
# 34        1       40       1.0      The Elder Scrolls V Skyrim - Hearthfire
#
#                                         tf_idf vector
# 0     (0, 20730)\t0.08226313359032639\n  (0, 20585...
# 1     (0, 20585)\t0.1766533605040369\n  (0, 20484)...
# 2     (0, 20473)\t0.1774632027598725\n  (0, 20361)...
# 3     (0, 20839)\t0.1005894584704967\n  (0, 20286)...
# 4     (0, 20554)\t0.20294699632970287\n  (0, 20542...
# 5     (0, 19963)\t0.03824841846933033\n  (0, 19726...
# 6     (0, 20581)\t0.17449319781073647\n  (0, 20402...
# 7     (0, 20839)\t0.2911024499925714\n  (0, 20815)...
# 8     (0, 20308)\t0.12340410820988834\n  (0, 19828...
# 9     (0, 20286)\t0.0950816869833791\n  (0, 20147)...
# 10    (0, 19979)\t0.2030633935121336\n  (0, 19955)...
# 11    (0, 19409)\t0.11057632142316463\n  (0, 18783...
# 12    (0, 20002)\t0.1549131750328819\n  (0, 19059)...
# 13    (0, 20865)\t0.08434757815068226\n  (0, 20733...
# 14    (0, 18039)\t0.1928224416563392\n  (0, 17622)...
# 15    (0, 20029)\t0.20753281262532175\n  (0, 18805...
# 16    (0, 18975)\t0.1438388950990718\n  (0, 18370)...
# 17    (0, 20539)\t0.13627870716481308\n  (0, 20030...
# 18    (0, 20484)\t0.09885770554381638\n  (0, 19838...
# 19    (0, 19955)\t0.09023388096094236\n  (0, 19954...
# 20    (0, 20733)\t0.1286715975080584\n  (0, 19441)...
# 21    (0, 20419)\t0.1922728254684602\n  (0, 19860)...
# 22    (0, 20601)\t0.16052099587129803\n  (0, 20581...
# 23    (0, 20585)\t0.05502178439245299\n  (0, 19912...
# 24    (0, 20147)\t0.25176590124921194\n  (0, 19299...
# 25    (0, 20733)\t0.1286715975080584\n  (0, 19441)...
# 26    (0, 20585)\t0.2185284054255687\n  (0, 19384)...
# 27    (0, 20308)\t0.07654809954640414\n  (0, 19852...
# 28    (0, 20568)\t0.154775311696342\n  (0, 20253)\...
# 29    (0, 20834)\t0.43074217071121845\n  (0, 20658...
# 30    (0, 18844)\t0.2225776058427188\n  (0, 18584)...
# 31    (0, 20585)\t0.047116298745952814\n  (0, 1944...
# 32    (0, 20730)\t0.08226313359032639\n  (0, 20585...
# 33    (0, 20730)\t0.08226313359032639\n  (0, 20585...
# 34    (0, 20730)\t0.08226313359032639\n  (0, 20585...

# %%
specific_user_id_name_vector_hours = specific_user_id_name_vector.merge(specific_user_game_play, how='inner')
specific_user_id_name_vector_hours
# Out:
#     User_ID  Game_ID  Purchase                              Game Name  \
# 0         1        1       1.0             The Elder Scrolls V Skyrim
# 1         1        2       1.0                              Fallout 4
# 2         1        4       1.0                      Fallout New Vegas
# 3         1        5       1.0                          Left 4 Dead 2
# 4         1        6       1.0                               HuniePop
# 5         1        7       1.0                          Path of Exile
# 6         1        8       1.0                            Poly Bridge
# 7         1        9       1.0                            Left 4 Dead
# 8         1       10       1.0                        Team Fortress 2
# 9         1       11       1.0                            Tomb Raider
# 10        1       12       1.0                        The Banner Saga
# 11        1       13       1.0                   Dead Island Epidemic
# 12        1       14       1.0                      BioShock Infinite
# 13        1       15       1.0  Dragon Age Origins - Ultimate Edition
# 14        1       17       1.0     SEGA Genesis & Mega Drive Classics
# 15        1       18       1.0                    Grand Theft Auto IV
# 16        1       19       1.0                   Realm of the Mad God
# 17        1       20       1.0                     Marvel Heroes 2015
# 18        1       21       1.0                                Eldevin
# 19        1       22       1.0                                 Dota 2
# 20        1       23       1.0                               BioShock
# 21        1       24       1.0                              Robocraft
# 22        1       25       1.0                            Garry's Mod
# 23        1       26       1.0                               Jazzpunk
#
#                                         tf_idf vector  Hours
# 0     (0, 20730)\t0.08226313359032639\n  (0, 20585...  273.0
# 1     (0, 20585)\t0.1766533605040369\n  (0, 20484)...   87.0
# 2     (0, 20473)\t0.1774632027598725\n  (0, 20361)...   12.1
# 3     (0, 20839)\t0.1005894584704967\n  (0, 20286)...    8.9
# 4     (0, 20554)\t0.20294699632970287\n  (0, 20542...    8.5
# 5     (0, 19963)\t0.03824841846933033\n  (0, 19726...    8.1
# 6     (0, 20581)\t0.17449319781073647\n  (0, 20402...    7.5
# 7     (0, 20839)\t0.2911024499925714\n  (0, 20815)...    3.3
# 8     (0, 20308)\t0.12340410820988834\n  (0, 19828...    2.8
# 9     (0, 20286)\t0.0950816869833791\n  (0, 20147)...    2.5
# 10    (0, 19979)\t0.2030633935121336\n  (0, 19955)...    2.0
# 11    (0, 19409)\t0.11057632142316463\n  (0, 18783...    1.4
# 12    (0, 20002)\t0.1549131750328819\n  (0, 19059)...    1.3
# 13    (0, 20865)\t0.08434757815068226\n  (0, 20733...    1.3
# 14    (0, 18039)\t0.1928224416563392\n  (0, 17622)...    0.8
# 15    (0, 20029)\t0.20753281262532175\n  (0, 18805...    0.6
# 16    (0, 18975)\t0.1438388950990718\n  (0, 18370)...    0.5
# 17    (0, 20539)\t0.13627870716481308\n  (0, 20030...    0.5
# 18    (0, 20484)\t0.09885770554381638\n  (0, 19838...    0.5
# 19    (0, 19955)\t0.09023388096094236\n  (0, 19954...    0.5
# 20    (0, 20733)\t0.1286715975080584\n  (0, 19441)...    0.5
# 21    (0, 20419)\t0.1922728254684602\n  (0, 19860)...    0.4
# 22    (0, 20601)\t0.16052099587129803\n  (0, 20581...    0.1
# 23    (0, 20585)\t0.05502178439245299\n  (0, 19912...    0.1

# %%
test_vector = specific_user_id_name_vector_hours['tf_idf vector'][0]
test_vector
# Out:
# <1x20891 sparse matrix of type '<class 'numpy.float64'>'
# 	with 70 stored elements in Compressed Sparse Row format>

# %%
# Convert this to function for creating data frame to multiply the game time
#place tf-idf values in a pandas data frame 
df = pd.DataFrame(test_vector.T.todense(), index=tfidf_vectorizer.get_feature_names(), columns=["tfidf"])
df.sort_values(by=["tfidf"],ascending=False)
# Out:
#             tfidf
# skyrim   0.264183
# scrolls  0.259900
# elder    0.256069
# virtual  0.201381
# want     0.174213
# ...           ...
# fazbear  0.000000
# faye     0.000000
# faydwer  0.000000
# favours  0.000000
# 온라인      0.000000
#
# [20891 rows x 1 columns]

# %%
def convert_to_pandas(encoded_vector):
    df = pd.DataFrame(encoded_vector.T.todense(), index=tfidf_vectorizer.get_feature_names(), columns=["tfidf"])
    return df.sort_values(by=["tfidf"],ascending=False)

# %%
convert_to_pandas(test_vector)
# Out:
#             tfidf
# skyrim   0.264183
# scrolls  0.259900
# elder    0.256069
# virtual  0.201381
# want     0.174213
# ...           ...
# fazbear  0.000000
# faye     0.000000
# faydwer  0.000000
# favours  0.000000
# 온라인      0.000000
#
# [20891 rows x 1 columns]

# %%
user_vector_data = specific_user_id_name_vector_hours[['tf_idf vector', 'Hours']]
user_vector_data
# Out:
#                                         tf_idf vector  Hours
# 0     (0, 20730)\t0.08226313359032639\n  (0, 20585...  273.0
# 1     (0, 20585)\t0.1766533605040369\n  (0, 20484)...   87.0
# 2     (0, 20473)\t0.1774632027598725\n  (0, 20361)...   12.1
# 3     (0, 20839)\t0.1005894584704967\n  (0, 20286)...    8.9
# 4     (0, 20554)\t0.20294699632970287\n  (0, 20542...    8.5
# 5     (0, 19963)\t0.03824841846933033\n  (0, 19726...    8.1
# 6     (0, 20581)\t0.17449319781073647\n  (0, 20402...    7.5
# 7     (0, 20839)\t0.2911024499925714\n  (0, 20815)...    3.3
# 8     (0, 20308)\t0.12340410820988834\n  (0, 19828...    2.8
# 9     (0, 20286)\t0.0950816869833791\n  (0, 20147)...    2.5
# 10    (0, 19979)\t0.2030633935121336\n  (0, 19955)...    2.0
# 11    (0, 19409)\t0.11057632142316463\n  (0, 18783...    1.4
# 12    (0, 20002)\t0.1549131750328819\n  (0, 19059)...    1.3
# 13    (0, 20865)\t0.08434757815068226\n  (0, 20733...    1.3
# 14    (0, 18039)\t0.1928224416563392\n  (0, 17622)...    0.8
# 15    (0, 20029)\t0.20753281262532175\n  (0, 18805...    0.6
# 16    (0, 18975)\t0.1438388950990718\n  (0, 18370)...    0.5
# 17    (0, 20539)\t0.13627870716481308\n  (0, 20030...    0.5
# 18    (0, 20484)\t0.09885770554381638\n  (0, 19838...    0.5
# 19    (0, 19955)\t0.09023388096094236\n  (0, 19954...    0.5
# 20    (0, 20733)\t0.1286715975080584\n  (0, 19441)...    0.5
# 21    (0, 20419)\t0.1922728254684602\n  (0, 19860)...    0.4
# 22    (0, 20601)\t0.16052099587129803\n  (0, 20581...    0.1
# 23    (0, 20585)\t0.05502178439245299\n  (0, 19912...    0.1

# %%
user_vector_data_tf_idf_vectors = user_vector_data['tf_idf vector']
user_vector_data_tf_idf_vectors
# Out:
# 0       (0, 20730)\t0.08226313359032639\n  (0, 20585...
# 1       (0, 20585)\t0.1766533605040369\n  (0, 20484)...
# 2       (0, 20473)\t0.1774632027598725\n  (0, 20361)...
# 3       (0, 20839)\t0.1005894584704967\n  (0, 20286)...
# 4       (0, 20554)\t0.20294699632970287\n  (0, 20542...
# 5       (0, 19963)\t0.03824841846933033\n  (0, 19726...
# 6       (0, 20581)\t0.17449319781073647\n  (0, 20402...
# 7       (0, 20839)\t0.2911024499925714\n  (0, 20815)...
# 8       (0, 20308)\t0.12340410820988834\n  (0, 19828...
# 9       (0, 20286)\t0.0950816869833791\n  (0, 20147)...
# 10      (0, 19979)\t0.2030633935121336\n  (0, 19955)...
# 11      (0, 19409)\t0.11057632142316463\n  (0, 18783...
# 12      (0, 20002)\t0.1549131750328819\n  (0, 19059)...
# 13      (0, 20865)\t0.08434757815068226\n  (0, 20733...
# 14      (0, 18039)\t0.1928224416563392\n  (0, 17622)...
# 15      (0, 20029)\t0.20753281262532175\n  (0, 18805...
# 16      (0, 18975)\t0.1438388950990718\n  (0, 18370)...
# 17      (0, 20539)\t0.13627870716481308\n  (0, 20030...
# 18      (0, 20484)\t0.09885770554381638\n  (0, 19838...
# 19      (0, 19955)\t0.09023388096094236\n  (0, 19954...
# 20      (0, 20733)\t0.1286715975080584\n  (0, 19441)...
# 21      (0, 20419)\t0.1922728254684602\n  (0, 19860)...
# 22      (0, 20601)\t0.16052099587129803\n  (0, 20581...
# 23      (0, 20585)\t0.05502178439245299\n  (0, 19912...
# Name: tf_idf vector, dtype: object

# %%
user_vector_data_tf_play_hours = user_vector_data['Hours']
user_vector_data_tf_play_hours
# Out:
# 0     273.0
# 1      87.0
# 2      12.1
# 3       8.9
# 4       8.5
# 5       8.1
# 6       7.5
# 7       3.3
# 8       2.8
# 9       2.5
# 10      2.0
# 11      1.4
# 12      1.3
# 13      1.3
# 14      0.8
# 15      0.6
# 16      0.5
# 17      0.5
# 18      0.5
# 19      0.5
# 20      0.5
# 21      0.4
# 22      0.1
# 23      0.1
# Name: Hours, dtype: float64

# %%
user_vector = float()
if len(user_vector_data_tf_play_hours) == len(user_vector_data_tf_idf_vectors):
    for index in range(len(user_vector_data_tf_play_hours)):
        game_vector = convert_to_pandas(user_vector_data_tf_idf_vectors[index])
        new_vector = game_vector * math.log(10, user_vector_data_tf_play_hours[index])
        user_vector += new_vector

# %%
user_vector
# Out:
#             tfidf
# skyrim   0.252559
# scrolls  0.248465
# elder    0.244803
# virtual  0.082663
# want     0.071511
# ...           ...
# fazbear  0.000000
# faye     0.000000
# faydwer  0.000000
# favours  0.000000
# 온라인      0.000000
#
# [20891 rows x 1 columns]

# %%
tfidf_vectorizer_vectors
# Out:
# <4209x20891 sparse matrix of type '<class 'numpy.float64'>'
# 	with 173884 stored elements in Compressed Sparse Row format>

# %%
t = user_vector.to_numpy()
t
# Out:
# array([[0.25255916],
#        [0.24846501],
#        [0.24480266],
#        ...,
#        [0.        ],
#        [0.        ],
#        [0.        ]])

# %%
user_vector_updated = np.rot90(t, 3)
user_vector_updated = np.flip(user_vector_updated)
user_vector_updated.shape
# Out:
# (1, 20891)

# %%
tfidf_vectorizer_vectors
# Out:
# <4209x20891 sparse matrix of type '<class 'numpy.float64'>'
# 	with 173884 stored elements in Compressed Sparse Row format>

# %%
user_vector_updated.shape
# Out:
# (1, 20891)
